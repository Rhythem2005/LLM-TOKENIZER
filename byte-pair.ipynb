# %%
# !pip3 install tiktoken
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
import tiktoken
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = """The quick brown fox jumps over the lazy dog. This sentence contains uppercase and lowercase letters, numbers like 12345, punctuation marks (!, ?, ., ,), and multiple spaces.

Natural language processing models split text into tokens before processing it. Different tokenizers may produce different token sequences for the same input.

<|endoftext|>"""
integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
print(integers)
# Out:
# [464, 2068, 7586, 21831, 18045, 625, 262, 16931, 3290, 13, 770, 6827, 4909, 334, 39921, 589, 290, 2793, 7442, 7475, 11, 3146, 588, 17031, 2231, 11, 21025, 2288, 8849, 22759, 11, 5633, 11, 764, 11, 837, 828, 290, 3294, 9029, 13, 198, 198, 35364, 3303, 7587, 4981, 6626, 2420, 656, 16326, 878, 7587, 340, 13, 20615, 11241, 11341, 743, 4439, 1180, 11241, 16311, 329, 262, 976, 5128, 13, 628, 50256]

# %%
strings = tokenizer.decode(integers)
print(strings)
# Out:
# The quick brown fox jumps over the lazy dog. This sentence contains uppercase and lowercase letters, numbers like 12345, punctuation marks (!, ?, ., ,), and multiple spaces.
#
# Natural language processing models split text into tokens before processing it. Different tokenizers may produce different token sequences for the same input.
#
# <|endoftext|>

# %%
for token in integers:
    print(token, repr(tokenizer.decode([token])))
# Out:
# 464 'The'
# 2068 ' quick'
# 7586 ' brown'
# 21831 ' fox'
# 18045 ' jumps'
# 625 ' over'
# 262 ' the'
# 16931 ' lazy'
# 3290 ' dog'
# 13 '.'
# 770 ' This'
# 6827 ' sentence'
# 4909 ' contains'
# 334 ' u'
# 39921 'pperc'
# 589 'ase'
# 290 ' and'
# 2793 ' lower'
# 7442 'case'
# 7475 ' letters'
# 11 ','
# 3146 ' numbers'
# 588 ' like'
# 17031 ' 123'
# 2231 '45'
# 11 ','
# 21025 ' punct'
# 2288 'uation'
# 8849 ' marks'
# 22759 ' (!'
# 11 ','
# 5633 ' ?'
# 11 ','
# 764 ' .'
# 11 ','
# 837 ' ,'
# 828 '),'
# 290 ' and'
# 3294 ' multiple'
# 9029 ' spaces'
# 13 '.'
# 198 '\n'
# 198 '\n'
# 35364 'Natural'
# 3303 ' language'
# 7587 ' processing'
# 4981 ' models'
# 6626 ' split'
# 2420 ' text'
# 656 ' into'
# 16326 ' tokens'
# 878 ' before'
# 7587 ' processing'
# 340 ' it'
# 13 '.'
# 20615 ' Different'
# 11241 ' token'
# 11341 'izers'
# 743 ' may'
# 4439 ' produce'
# 1180 ' different'
# 11241 ' token'
# 16311 ' sequences'
# 329 ' for'
# 262 ' the'
# 976 ' same'
# 5128 ' input'
# 13 '.'
# ...
